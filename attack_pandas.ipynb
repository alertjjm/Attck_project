# %%
import pandas as pd
import numpy as np
import json

# %%
f=open("result.json",'r')
jsondata=json.load(f)
f.close()

# %%
df=pd.DataFrame(jsondata,index=['values'])
df=df.T

# %%
print(jsondata)
# Out:
# {'T1015': 5, 'T1003': 36, 'T1001': 2, 'T1190': 3, 'T1076': 17, 'T1009': 5, 'T1087': 12, 'T1059': 32, 'T1002': 22, 'T1022': 13, 'T1213': 2, 'T1005': 18, 'T1114': 7, 'T1041': 8, 'T1133': 10, 'T1083': 19, 'T1056': 17, 'T1036': 19, 'T1050': 10, 'T1097': 4, 'T1069': 6, 'T1057': 19, 'T1060': 30, 'T1018': 14, 'T1064': 41, 'T1035': 5, 'T1071': 30, 'T1082': 20, 'T1016': 20, 'T1049': 13, 'T1007': 6, 'T1077': 9, 'T1203': 18, 'T1193': 37, 'T1204': 37, 'T1102': 12, 'T1119': 7, 'T1135': 5, 'T1075': 5, 'T1134': 3, 'T1527': 1, 'T1067': 3, 'T1043': 19, 'T1092': 1, 'T1122': 1, 'T1090': 10, 'T1024': 3, 'T1025': 4, 'T1074': 16, 'T1140': 14, 'T1173': 8, 'T1211': 1, 'T1068': 8, 'T1210': 2, 'T1107': 25, 'T1158': 4, 'T1143': 9, 'T1070': 8, 'T1037': 2, 'T1040': 3, 'T1027': 36, 'T1137': 2, 'T1120': 4, 'T1086': 36, 'T1105': 30, 'T1091': 2, 'T1014': 3, 'T1085': 8, 'T1113': 10, 'T1192': 20, 'T1528': 1, 'T1221': 4, 'T1099': 4, 'T1199': 2, 'T1078': 25, 'T1089': 9, 'T1219': 5, 'T1066': 7, 'T1117': 6, 'T1100': 9, 'T
# ...

# %%
df
# Out:
#        values
# T1015       5
# T1003      36
# T1001       2
# T1190       3
# T1076      17
# T1009       5
# T1087      12
# T1059      32
# T1002      22
# T1022      13
# T1213       2
# T1005      18
# T1114       7
# T1041       8
# T1133      10
# T1083      19
# T1056      17
# T1036      19
# T1050      10
# T1097       4
# T1069       6
# T1057      19
# T1060      30
# T1018      14
# T1064      41
# T1035       5
# T1071      30
# T1082      20
# T1016      20
# T1049      13
# ...       ...
# T1017       1
# T1222       1
# T1031       4
# T1096       1
# T1216       1
# T1197       1
# T1195       2
# T1123       1
# T1179       1
# T1191       2
# T1500       1
# T1175       1
# T1503       3
# T1182       1
# T1020       1
# T1187       2
# T1218       3
# T1220       1
# T1115       1
# T1486       3
# T1494       1
# T1492       2
# T1493       1
# T1141       1
# T1176       2
# T1183       1
# T1214       1
# T1042       1
# T1146       1
# T1483       1
#
# ...

# %%
df=df.sort_values(by='values',ascending=False)

# %%
df
# Out:
#        values
# T1064      41
# T1204      37
# T1193      37
# T1027      36
# T1003      36
# T1086      36
# T1059      32
# T1060      30
# T1105      30
# T1071      30
# T1078      25
# T1107      25
# T1053      24
# T1002      22
# T1016      20
# T1192      20
# T1082      20
# T1057      19
# T1043      19
# T1036      19
# T1083      19
# T1005      18
# T1203      18
# T1056      17
# T1033      17
# T1076      17
# T1074      16
# T1018      14
# T1047      14
# T1189      14
# ...       ...
# T1141       1
# T1528       1
# T1183       1
# T1214       1
# T1042       1
# T1146       1
# T1179       1
# T1216       1
# T1211       1
# T1197       1
# T1028       1
# T1126       1
# T1488       1
# T1026       1
# T1030       1
# T1489       1
# T1061       1
# T1109       1
# T1527       1
# T1138       1
# T1172       1
# T1092       1
# T1122       1
# T1201       1
# T1017       1
# T1222       1
# T1080       1
# T1096       1
# T1072       1
# T1483       1
#
# ...

# %%
df_cut=df[0:30]
df_cut2=df[30:60]

# %%
df_cut
# Out:
#        values
# T1064      41
# T1204      37
# T1193      37
# T1027      36
# T1003      36
# T1086      36
# T1059      32
# T1060      30
# T1105      30
# T1071      30
# T1078      25
# T1107      25
# T1053      24
# T1002      22
# T1016      20
# T1192      20
# T1082      20
# T1057      19
# T1043      19
# T1036      19
# T1083      19
# T1005      18
# T1203      18
# T1056      17
# T1033      17
# T1076      17
# T1074      16
# T1018      14
# T1047      14
# T1189      14

# %%
df_cut.plot(kind='bar',figsize=(15,5))

# %%
df_cut2.plot(kind='bar',figsize=(15,5))
